# %%
import cv2

key = cv2.waitKey(1)
webcam = cv2.VideoCapture(0)
while True:
    try:
        check, frame = webcam.read()
        # print(check)  # prints true as long as the webcam is running
        # print(frame)  # prints matrix values of each framecd
        cv2.imshow("Capturing", frame)
        key = cv2.waitKey(1)
        if key == ord('s'):
            cv2.imwrite(filename='saved_img.jpg', img=frame)
            webcam.release()
            img_new = cv2.imread('saved_img.jpg', cv2.IMREAD_GRAYSCALE)
            img_new = cv2.imshow("Captured Image", img_new)
            cv2.waitKey(1650)
            cv2.destroyAllWindows()
            print("Processing image...")
            img_ = cv2.imread('saved_img.jpg', cv2.IMREAD_ANYCOLOR)
            print("Converting RGB image to grayscale...")
            gray = cv2.cvtColor(img_, cv2.COLOR_BGR2GRAY)
            print("Converted RGB image to grayscale...")
            print("Resizing image to 1028x1028 scale...")
            img_ = cv2.resize(gray, (1028,1028))
            print("Resized...")
            img_resized = cv2.imwrite(filename='saved_img-final.jpg', img=img_)
            print("Image saved!")

            break
        elif key == ord('q'):
            print("Turning off camera.")
            webcam.release()
            print("Camera off.")
            print("Program ended.")
            cv2.destroyAllWindows()
            break

    except(KeyboardInterrupt):
        print("Turning off camera.")
        webcam.release()
        print("Camera off.")
        print("Program ended.")
        cv2.destroyAllWindows()
        break
# Out:
# Processing image...
# Converting RGB image to grayscale...
# Converted RGB image to grayscale...
# Resizing image to 1028x1028 scale...
# Resized...
# Image saved!

# %%
# pip install pandas

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %%
pip install --upgrade fer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached fer-22.5.0-py3-none-any.whl (1.5 MB)
# ...
#   Using cached facenet_pytorch-2.5.2-py3-none-any.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 14.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# ...
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# ...
#   Using cached filelock-3.10.7-py3-none-any.whl (10 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
#   WARNING: The script isympy is installed in '/Users/arhamjain/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from fer import FER
import cv2
emotion_detector = FER(mtcnn=True)
test_img = cv2.imread("saved_img-final.jpg")
analysis = emotion_detector.detect_emotions(test_img)
print("Analysis of Image:",analysis)
test_img_low_quality= cv2.imread("saved_img-final.jpg")
analysis = emotion_detector.detect_emotions(test_img_low_quality)
analysis
dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img_low_quality)
print("Dominant Emotion:",dominant_emotion, emotion_score)
# test_img2 = cv2.imread("saved_img.jpg")
# analysis = emotion_detector.detect_emotions(test_img2)
# print("Anaylsis of Normal Image:",analysis)
# test_img_low_quality= cv2.imread("saved_img-final.jpg")
# analysis = emotion_detector.detect_emotions(test_img_low_quality)
# analysis
# dominant_emotion, emotion_score = emotion_detector.top_emotion(test_img_low_quality)
# print(dominant_emotion, emotion_score)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 from fer import FER
#       2 import cv2
#       3 emotion_detector = FER(mtcnn=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fer/__init__.py:28
#      25 import logging
#      27 from .classes import Video
# ---> 28 from .fer import FER
#      30 log = logging.getLogger("fer")
#      31 log.setLevel(logging.INFO)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fer/fer.py:42
#      39 import cv2
#      40 import numpy as np
# ---> 42 from tensorflow.keras.models import load_model
#      45 from .utils import load_image
#      47 logging.basicConfig(level=logging.INFO)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/api/_v2/keras/__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
# ...

# %%
# pip install deepface

# %%
# from deepface import DeepFace
# face_analysis = DeepFace.analyze(img_path = "saved_img-final.jpg")

# %%
# pip install pandas

# %%
# pip install tensorflow-macos

# %%
# pip install opencv-python

# %%
# pip install FER

# %%
# pip install seaborn

# %%
# pip install utils

# %%
# pip install livelossplot

# %%
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import utils
# import os
# %matplotlib inline

# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
# from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
# from tensorflow.keras.models import Model, Sequential
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
# from tensorflow.keras.utils import plot_model

# from IPython.display import SVG, Image
# from livelossplot import PlotLossesKerasTF
# import tensorflow as tf
# print("Tensorflow version:", tf.__version__)

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
im = plt.imread("saved_img.jpg")
fig, ax = plt.subplots()
im = ax.imshow(im, extent=[0, 300, 0, 300])
x = np.array(range(300))
# ax.plot(x, x, ls='dotted', linewidth=2, color='red')
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
